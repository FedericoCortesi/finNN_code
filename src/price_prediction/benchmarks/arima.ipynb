# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
from models import create_model 

import yaml
from pipeline.walkforward import WFCVGenerator
from pipeline.wf_config import WFConfig
from utils.paths import CONFIG_DIR





# -------- load config --------
cfg = yaml.safe_load(open(CONFIG_DIR / "debug.yaml"))

# import wfcv
wf_config = WFConfig(**cfg["walkforward"])

wf = WFCVGenerator(config=wf_config)

test_data = {}
data = {}
for i, fold_data in enumerate(wf.folds()):

    X_test = fold_data[4]
    y_test = fold_data[5]

    test_data[i] = [X_test, y_test]
    data[i] = fold_data

# %%
import statsmodels.api as sm

# fix a fold
fold = 0

X_tr, y_tr, X_val, y_val, X_test, y_test = data[fold] 

X = sm.add_constant(X_tr)
model = sm.OLS(y_tr, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     71.00
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          2.24e-288
# Time:                        18:16:00   Log-Likelihood:             7.1923e+05
# No. Observations:              364349   AIC:                        -1.438e+06
# Df Residuals:                  364328   BIC:                        -1.438e+06
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002   5.57e-05      2.950      0.003    5.51e-05       0.000
# x1            -0.0120      0.002     -7.245      0.000      -0.015      -0.009
# x2            -0.0216      0.002    -13.057      0.000      -0.025      -0.018
# x3            -0.0146      0.002     -8.791      0.000      -0.018      -0.011
# x4             0.0009      0.002      0.548      0.584      -0.002       0.004
# x5             0.0187      0.002     11.281      0.000       0.015       0.022
# x6             0.0013      0.002      0.796      0.426      -0.002       0.005
# x7            -0.0098      0.002     -5.911      0.000      -0.013      -0.007
# x8             0.0172      0.002     10.363      0.000       0.014       0.020
# x9             0.0125      0.002      7.559      0.000       0.009       0.016
# x10           -0.0017      0.002     -0.996      0.319      -0.005       0.002
# x11           -0.0163      0.002     -9.833      0.000      -0.020      -0.013
# x12            0.0052      0.002      3.111      0.002       0.002       0.008
# x13           -0.0097      0.002     -5.839      0.000      -0.013      -0.006
# x14            0.0030      0.002      1.821      0.069      -0.000       0.006
# x15           -0.0166      0.002     -9.998      0.000      -0.020      -0.013
# x16           -0.0098      0.002     -5.888      0.000      -0.013      -0.007
# x17           -0.0001      0.002     -0.086      0.932      -0.003       0.003
# x18            0.0031      0.002      1.875      0.061      -0.000       0.006
# x19           -0.0346      0.002    -20.868      0.000      -0.038      -0.031
# x20            0.0076      0.002      4.588      0.000       0.004       0.011
# ==============================================================================
# Omnibus:                    93816.727   Durbin-Watson:                   1.573
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7490849.650
# Skew:                           0.165   Prob(JB):                         0.00
# Kurtosis:                      25.211   Cond. No.                         31.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
