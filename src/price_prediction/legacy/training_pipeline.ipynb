# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, numpy as np, pandas as pd, tensorflow as tf
print(sys.executable)
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("TF:", tf.__version__, "| GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2025-10-11 21:54:29.809470: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-11 21:54:29.821846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760234069.835294 4128498 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760234069.839294 4128498 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
# Out:
# 2025-10-12 00:04:04.498444: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-12 00:04:04.512908: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760241844.526164  220633 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760241844.530089  220633 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from  pipeline.walkforward import WFCVGenerator
from  pipeline.wf_config import WFConfig



import yaml
from utils.paths import CONFIG_DIR

cfg = yaml.safe_load(open(CONFIG_DIR/"default.yaml"))
mf = cfg["walkforward"]["max_folds"]



wf_cfg = WFConfig(**cfg["walkforward"])
wf_cfg
# Out:
# WFConfig(ratio_train=3, ratio_val=1, ratio_test=1, step=251, lags=20, max_folds=None)

# %%
from pipeline.walkforward import  WFCVGenerator, WFConfig

import numpy as np

config = WFConfig()
wfcv = WFCVGenerator(config=wf_cfg)
wfcv.df
# Out:
#            t       ret  permno
# 0          0 -0.012107   10078
# 1          1 -0.062092   10078
# 2          2  0.001742   10078
# 3          3 -0.053913   10078
# 4          4  0.056985   10078
# ...      ...       ...     ...
# 155298  6284  0.073572   93436
# 155299  6285  -0.01763   93436
# 155300  6286 -0.049479   93436
# 155301  6287 -0.033012   93436
# 155302  6288  -0.03251   93436
#
# [3155303 rows x 3 columns]
